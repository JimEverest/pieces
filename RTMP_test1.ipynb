# %%
import cv2
import matplotlib.pyplot as plt
import time

# %%
addr='rtmp://24646.liveplay.myqcloud.com/live/24646_warehouse_10002'

# %%
cur = time.time()
videoAddr="rtmp://24646.liveplay.myqcloud.com/live/24646_warehouse_10002"
video = cv2.VideoCapture(videoAddr)
frame,err = video.read()
timelast = time.time() - cur
timelast
# Out:
# 20.0405592918396

# %%
err

# %%
frame
# Out:
# True

# %%
show = cv2.cvtColor(err, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(10,10))
plt.imshow(err)
plt.show()

# %%
ffplay rtmp://24646.liveplay.myqcloud.com/live/24646_warehouse_10002 -loglevel verbose

# %%
import vlc
player=vlc.MediaPlayer('rtmp://24646.liveplay.myqcloud.com/live/24646_warehouse_10002')

# %%
player.play()
# Out:
# 0

# %%
player.video_take_snapshot(0, '.snapshot.tmp.png', 0, 0)
# Out:
# -1

# %%
import vlc
i = vlc.Instance('--verbose 2'.split())
p = i.media_player_new()
p.set_mrl(addr)
p.play()
# Out:
# 0

# %%
p.video_take_snapshot(0, '.snapshot.tmp.png', 0, 0)
# Out:
# 0

# %%
import vlc
vlcInstance = vlc.Instance()
player = vlcInstance.media_player_new()
player.set_mrl(addr)
player.play()
# Out:
# 0

# %%
player.stop()

# %%
i=0
xxx=[]
while i<3:
    time.sleep(0.1)
    xxx = player.video_take_snapshot(0, str(i) + 'a.snapshot.tmp.png', 0, 0)
    i+=1

# %%
last_img = cv2.imread(str(2)+ 'a.snapshot.tmp.png', cv2.IMREAD_GRAYSCALE)

# %%
# winname = "Test"
# cv2.imshow(winname, last_img)
# cv2.waitKey()
# cv2.destroyAllWindows()

# %%
plt.imshow(last_img,cmap ='gray')
plt.show()
