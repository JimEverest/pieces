# %%
import itchat
import re
# Out:
# █

# %%
itchat.login()
# Out:
# Getting uuid of QR code.
# Downloading QR code.
# Please scan the QR code to log in.
# Please press confirm on your phone.
# Loading the contact, this may take a little while.
# Login successfully as Jim

# %%
itchat.send(u'[msg1]', 'filehelper')
# Out:
# <ItchatReturnValue: {'BaseResponse': {'Ret': 0, 'ErrMsg': '请求成功', 'RawMsg': '请求成功'}, 'MsgID': '6168310475642939474', 'LocalID': '15324191380201'}>

# %%
friends = itchat.get_friends(update=True)[0:]

# %%
male = female = other = 0

# %%
for i in friends[1:]:
    sex = i["Sex"]
    if sex == 1:
        male += 1
    elif sex == 2:
        female += 1
    else:
        other += 1

# %%
total = len(friends[1:])

# %%
print (u"男性好友：%.2f%%" % (float(male) / total * 100))
print (u"女性好友：%.2f%%" % (float(female) / total * 100))
print (u"其他：%.2f%%" % (float(other) / total * 100))
# Out:
# 男性好友：58.62%
# 女性好友：31.53%
# 其他：9.85%

# %%
from echarts import Echart, Legend, Pie

chart = Echart(u'%s的微信好友性别比例' % (friends[0]['NickName']), 'from WeChat')
chart.use(Pie('WeChat',
              [{'value': male, 'name': u'男性 %.2f%%' % (float(male) / total * 100)},
               {'value': female, 'name': u'女性 %.2f%%' % (float(female) / total * 100)},
               {'value': other, 'name': u'其他 %.2f%%' % (float(other) / total * 100)}],
              radius=["50%", "70%"]))
chart.use(Legend(["male", "female", "other"]))
del chart.json["xAxis"]
del chart.json["yAxis"]
chart.plot()

# %%
tList = []
for i in friends:
    signature = i["Signature"].replace(" ", "").replace("span", "").replace("class", "").replace("emoji", "")
    rep = re.compile("1f\d.+")
    signature = rep.sub("", signature)
    tList.append(signature)

# %%
text = "".join(tList)

# %%
text
# Out:
# '且行且珍惜.nohmj透支生命透支未来未来两年，我会每天陪伴大家学习，帮助大家提高！l＇llbeherefoyou一飞冲天九霄外\u2029踏云逐雾天中显\u2029惊雷布雨慑万里\u2029四海三江唯我allforone,oneforall不忘初心，砥砺前行<="\n生命不息，奋斗不止<="世界之美，取决于您别样的视角！代查、代购、定制、打印各类中英文电子版书籍和复印书书籍！别克走进一座城市，收获你希望明天的自己，像一道彩虹，还是刚淋过雨~我讨厌披着羊皮的狼没心没肺，嘛也不会，醒了就吃，饱了就睡。舍得爱&amp;记憶要明白自己想要什么，在努力争取的同时，也要懂得能为之放弃什么Makeeverydaycount.<="你要学会长大，一个人抵过千军万马夏天很热，冬天很冷，社会很现实，人生很短暂给我的她幸福快乐见日之光天下大明爱惜自己！珍惜生活。努力和遗憾哪个更痛苦！小墨斗简单点，不计较且多包容。大风起兮云飞扬，威加海内兮归故乡，安得猛士兮守四方。爱想爱相信天津各景区门票～礼品～提货券均有带着虔诚的心走在朝圣的道路上。每个人都是一座孤岛人生就是滾雪球，天之博特，琢玉成器，育才以兴业。Spiritofthecraftsman孟利军主营英国nexttugap等品牌外贸原单跟单童装，长期招收代理常与同好争高下，不共傻瓜论短长全部工厂直发做世界最好的相机背带所谓诚其意者，毋自欺也！欢迎各位顾客，本店一分钱一分货，不卖垃圾产品hitmelikeahurricane我是李华映函授专升本教育。火热招生中，欲速从优！我的读书笔记公众号【�
滩。余溪之海我爱我的大白鹅家庭最重要不乱于心，不困于情，不畏将来，不念过往，如此，安好平凡的生活可以喂饱所有人，哪怕你再看它不顺眼！\n「此号已满，可加Teacher_L2」\n消息太多难免遗漏回复\n请见谅上班时间：9:30-20:00（周天休息）入台证办理，金门自由行服务。退一步风光明媚！！没事养养鱼过佛系生活🌚坚持输入静等花开三觀不同那就互相尊重\nPeaceandlove\nIwannagotoyourheart.爱尚大柠檬Yizhiduxiu5555加这个过去的都该过去，该来的都在路上'

# %%
import jieba
wordlist_jieba = jieba.cut(text, cut_all=True)
wl_space_split = " ".join(wordlist_jieba)
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache C:\Users\jtian\AppData\Local\Temp\jieba.cache
# Loading model cost 0.818 seconds.
# Prefix dict has been built succesfully.

# %%
wl_space_split
# Out:
# '且 行 且 珍惜  nohmj 透支 生命 透支 未来 未来 两年   我会 每天 陪伴 大家 家学 学习   帮助 大家 提高  l llbeherefoyou 一飞冲天 冲天 九霄 外   踏 云 逐 雾天 中 显   惊雷 布 雨 慑 万里   四海 三江 唯我 allforone oneforall 不 忘 初心   砥砺 前行    \n 生命 生命不息 不息   奋斗 不止     世界 之 美   取决 取决于 您 别样 的 视角   代查   代购   定制   打印 各类 中英 中英文 英文 文电 电子 电子版 书籍 和 复印 印书 书籍   别克 走进 一座 城市   收获 你 希望 明天 的 自己   像 一道 彩虹   还是 刚 淋过 雨   我 讨厌 披着 羊皮 的 狼 没心 没心没肺   嘛 也 不会   醒 了 就 吃   饱 了 就 睡   舍得 爱  amp  记 憶 要 明白 自己 想要 什么   在 努力 努力争取 力争 争取 的 同时   也 要 懂得 能 为 之 放弃 什么 Makeeverydaycount     你 要 学会 会长 长大   一个 个人 抵过 千军 千军万马 万马 夏天 很 热   冬天 很 冷   社会 很 现实   人生 很 短暂 给 我 的 她 幸福 幸福快乐 快乐 乐见 日 之 光 天下 大明 爱惜 自己   珍惜 生活   努力 和 遗憾 哪个 更 痛苦   小 墨斗 简单 单点   不计 计较 且 多 包容   大风 起 兮 云飞扬 飞扬   威 加 海内 兮 归 故乡   安得 猛士 兮 守 四方   爱 想 爱 相信 天津 各 景区 门票   礼品   提货 券 均 有 带 着 虔诚 的 心 走 在 朝圣 的 道路 路上   每个 个人 都 是 一座 孤岛 人生 生就 就是 滾 雪球   天 之 博 特   琢玉 琢玉成器 玉成 成器   育才 以 兴业  Spiritofthecraftsman 孟 利 军 主营 英国 nexttugap 等品 品牌 外贸 原 单 跟 单 童装   长期 招收 代理 常 与 同好 争 高下   不 共 傻瓜 论 短长 全部 工厂 直 发 做 世界 最好 的 相机 背带 所谓 诚 其意 者   毋 自欺 也   欢迎 各位 顾客   本店 一分 一分钱 一分钱一 分钱 一分 一分货   不 卖 垃圾 产品 hitmelikeahurricane 我 是 李 华 映 函授 专升本 教育   火热 招生 中   欲 速 从优   我 的 读书 读书笔记 笔记 公众 号   吃 书 部落    来 这里   以 书会 会友   欢乐 在 云端 之上 快乐 的 时候 要 稳重   痛苦 的 时候 要 坚强   眼睛 那个 花 啊 生命 生命不息 不息   骑行 不止   低 碳 生活   唯有 骑行  Betruetoyourwork yourword andyourfriend  仰天 仰天大笑 天大 
疗 保驾 保驾护航 护航 专业 业生 生产 雪地 靴   冬季 新品 首发    全国 诚招 代理   最低 最低价 低价 价格 噢   一手 多米 蓝 珀 原 石 批发   个性 订制 联系 13827091738 挑战 无止境 止境   边界 由 我 定   努力 工作   快乐 生活     只 做 高端 质量 诚信 合作   交 订金 可 货到付款 付款   爱 学习   指 方向 专营 样品 库存 办公 公家 家具   展会 租赁   电话 13032281701 谁 会管 你 是 个 女生 你 得 坚强 给 别人 矫情 给 自己 淘宝 店铺 熊猫 教育 的 小铺 招 代理 理工 工厂 直销 支持 一件 代发 开心 每 一天 别 懂事 太 早   别 涉世 太 深   别 爱 的 太 满   别 睡 的 太晚   别 吃 的 太饱 一号 馆 一楼 D 区 88 号 巴西 西原 原产 紫晶 洞 联系 联系电话 电话 18260396661 匠心 盆栽 俱乐部 越 努力   越 幸运   此 微 信 好友 已 满   加 微 信  tstianwang  谢谢  sc ship us 众 鑫 装饰 承揽 室内 室内外 内外 装修 及 一切 防水 防水工程 水工 工程   电话 13920458981 广东 团队 技师 师专 专业 为 你 服务   内饰 翻新   座椅 真皮   加热   通风 八戒 你 有 在 偷看 为 师 的 签名 了 难得 难得糊涂 糊涂   留有 留有余地 有余 余地 元 征 优惠 优惠券 公众 号   精选 券 达人 专注 于 车辆 车辆保养 保养 维修 美容 的 品牌 体验 店 金钱 是 祸 不可 不可多得   爱情 是 酒 谁 喝 谁 醉 13752702516 办学 学生 学生证   若 微 信 没回 回复 您   请 加 QQ 1260050124 关注 旅游 尾 单 甩 位   提前 1 3 天 出 单 天津 首家 9D 体验 馆   坐落 在 新家 家乐 三 楼  360 度   身临 身临其境 的 体验 今天 的 我 努力 无愧 明天 的 自己 汽车 车内 内饰 改装   电动 座椅   通风 加热   桃木 内饰   实木 木地板 地板   药品 为 特殊 产品   不退 不换   忘 理解   脚踏 脚踏实地 踏实 实地    ...

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import PIL.Image as Image

# %%
my_wordcloud = WordCloud(background_color="white", max_words=2000, 
                         max_font_size=40, random_state=42,
                         font_path='C:/Windows/Fonts/ARIALUNI.TTF').generate(wl_space_split)
plt.figure(figsize=(20,10))
plt.imshow(my_wordcloud)
plt.axis("off")
plt.show()

# %%
import pixiedust
# Out:
# Pixiedust database opened successfully
# Table VERSION_TRACKER created successfully
# Table METRICS_TRACKER created successfully
#
# Share anonymous install statistics? (opt-out instructions)
#
# PixieDust will record metadata on its environment the next time the package is installed or updated. The data is anonymized and aggregated to help plan for future releases, and records only the following values:
#
# {
#    "data_sent": currentDate,
#    "runtime": "python",
#    "application_version": currentPixiedustVersion,
#    "space_id": nonIdentifyingUniqueId,
#    "config": {
#        "repository_id": "https://github.com/ibm-watson-data-lab/pixiedust",
#        "target_runtimes": ["Data Science Experience"],
#        "event_id": "web",
#        "event_organizer": "dev-journeys"
#    }
# }
# You can opt out by calling pixiedust.optOut() in a new cell.
#         <div style="margin:10px">
#             <a href="https://github.com/ibm-watson-data-lab/pixiedust" target="_new">
#                 <img src="https://github.com/ibm-watson-data-lab/pixiedust/raw/master/docs/_static/pd_icon32.png" style="float:left;margin-right:10px"/>
#             </a>
#             <span>Pixiedust version 1.1.11</span>
#         </div>
# Pixiedust runtime updated. Please restart kernel
# Table USER_PREFERENCES created successfully
# Table service_connections created successfully

# %%
# %%pixie_debugger
# import random
# def find_max (values):
#     max = 0
#     for val in values:
#         if val > max:
#             max = val
#     return max
# find_max(random.sample(range(100), 10))
# Out:
# <style type="text/css">.pd_warning{display:none;}</style><div class="pd_warning"><em>Hey, there's something awesome here! To see it, open this notebook outside GitHub, in a viewer like Jupyter</em></div>
